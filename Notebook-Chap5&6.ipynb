# %% [markdown]
# # -------------Get Started with Python for Data Science - Plan of Attack-------------

# %%
import math
math.sqrt(25)
# Out:
# 5.0

# %%
math.pi
# Out:
# 3.141592653589793

# %%
import math as mt
mt.sqrt(25)
# Out:
# 5.0

# %%
from numpy import random
import numpy as np
#uniform random numbers in [0,1]
dataOne = random.rand(5,5)
np.mean(dataOne)
# Out:
# 0.48839151820822196

# %% [markdown]
# ### Functions

# %%
print('I Love data Science')
# Out:
# I Love data Science

# %% [markdown]
# ### Variables

# %%
variableName = 25
variableName1 = 'I Love data Science'
print(variableName1)
# Out:
# I Love data Science

# %% [markdown]
# ### Datatypes

# %%
variableName = 25
type(variableName)
# Out:
# int

# %%
varOne = 25
varTwo = 25.0
varThree = varOne + varTwo
print(varThree)
# Out:
# 50.0

# %%
varOne = 25
varTwo = 'Hello'
varThree = varOne + varTwo
print(varThree)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-8f176fe74921> in <module>
#       1 varOne = 25
#       2 varTwo = 'Hello'
# ----> 3 varThree = varOne + varTwo
#       4 print(varThree)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# #### Error unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# ### Lists and Dictionaries

# %%
listOne = [1,2,3,4]
print(listOne[1:3])
# Out:
# [2, 3]

# %% [markdown]
# ### Dictionaries

# %%
tel = {'jack': 4098, 'sape': 4139}
tel['jack']
# Out:
# 4098

# %% [markdown]
# #  ---------------------   Using Jupyter Notebook -Chapters 5&6  ---------------------

# %% [markdown]
# ## Working with styles

# %% [markdown]
# # Performing Multimedia and Graphic Integration

# %% [markdown]
# ## Embedding plots and other images

# %%
# %matplotlib inline

# %% [markdown]
# ## Loading examples from online sites

# %%
# %load https://matplotlib.org/_downloads/pyplot_text.py
"""
===========
Pyplot Text
===========

"""
import numpy as np
import matplotlib.pyplot as plt

# Fixing random state for reproducibility
np.random.seed(19680801)

mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, density=True, facecolor='b', alpha=0.75)


plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %% [markdown]
# ## Obtaining online graphics and multimedia

# %%
from IPython.display import Image
Embed = Image(
'https://www.liveabout.com/thmb/XGh41yZ8EAOVP0I5s6vIWD6ncgM=/'+
    '720x450/filters:no_upscale():max_bytes(150000):strip_icc()/Cat1-5aab0021ba61770037e18b33.jpg')
Embed

# %% [markdown]
# # Uploading, Streaming, and Sampling Data

# %% [markdown]
# ## Uploading small amounts of data into memory

# %%
with open("Colors.txt", 'r') as open_file:
    print('Colors.txt content:\n' + open_file.read())
# Out:
# Colors.txt content:
# Color	Value
# Red	1
# Orange	2
# Yellow	3
# Green	4
# Blue	5
# Purple	6
# Black	7
# White	8

# %% [markdown]
# ## Streaming large amounts of data into memory

# %%
with open("Colors.txt", 'r') as open_file:
    for observation in open_file:
        print('Reading Data: ' + observation)
# Out:
# Reading Data: Color	Value
#
# Reading Data: Red	1
#
# Reading Data: Orange	2
#
# Reading Data: Yellow	3
#
# Reading Data: Green	4
#
# Reading Data: Blue	5
#
# Reading Data: Purple	6
#
# Reading Data: Black	7
#
# Reading Data: White	8

# %% [markdown]
# ## Generating variations on image data

# %%
import matplotlib.pyplot as plt
import matplotlib.image as img
# %matplotlib inline

image = img.imread("Colorblk.jpg")
print(image.shape)
print(image.size)
plt.imshow(image)
plt.show()
# Out:
# (100, 100, 3)
# 30000

# %% [markdown]
# ## Sampling data in different ways

# %%
n = 2
with open("Colors.txt", 'r') as open_file:
    for j, observation in enumerate(open_file):
        if j % n==0:
            print('Reading Line: ' + str(j) +
            ' Content: ' + observation)
# Out:
# Reading Line: 0 Content: Color	Value
#
# Reading Line: 2 Content: Orange	2
#
# Reading Line: 4 Content: Green	4
#
# Reading Line: 6 Content: Purple	6
#
# Reading Line: 8 Content: White	8

# %%
from random import random
sample_size = 0.25
with open("Colors.txt", 'r') as open_file:
    for j, observation in enumerate(open_file):
        if random()<=sample_size:
            print('Reading Line: ' + str(j) +
            ' Content: ' + observation)
# Out:
# Reading Line: 0 Content: Color	Value
#
# Reading Line: 3 Content: Yellow	3
#
# Reading Line: 6 Content: Purple	6

# %% [markdown]
# # Accessing Data in Structured Flat-File Form

# %% [markdown]
# ## Reading from a text file

# %%
import pandas as pd
color_table = pd.io.parsers.read_table("Colors.txt")
print(color_table)
# Out:
#     Color  Value
# 0     Red      1
# 1  Orange      2
# 2  Yellow      3
# 3   Green      4
# 4    Blue      5
# 5  Purple      6
# 6   Black      7
# 7   White      8

# %% [markdown]
# ## Reading CSV delimited format

# %%
import pandas as pd
titanic = pd.io.parsers.read_csv("Titanic.csv")
X = titanic[['age']]
print(X)
# Out:
#             age
# 0       29.0000
# 1        0.9167
# 2        2.0000
# 3       30.0000
# 4       25.0000
# ...         ...
# 1304    14.5000
# 1305  9999.0000
# 1306    26.5000
# 1307    27.0000
# 1308    29.0000
#
# [1309 rows x 1 columns]

# %%
X = titanic[['age']].values
print(X)
# Out:
# [[29.        ]
#  [ 0.91670001]
#  [ 2.        ]
#  ...
#  [26.5       ]
#  [27.        ]
#  [29.        ]]

# %% [markdown]
# ## Reading Excel and other Microsoft Office files

# %%
import pandas as pd
xls = pd.ExcelFile("Values.xls")
trig_values = xls.parse('Sheet1', index_col=None,
                        na_values=['NA'])
print(trig_values)
# Out:
#     Angle (Degrees)      Sine    Cosine    Tangent
# 0        138.550574  0.661959 -0.749540  -0.883153
# 1        305.535745 -0.813753  0.581211  -1.400100
# 2        280.518695 -0.983195  0.182556  -5.385709
# 3        216.363795 -0.592910 -0.805269   0.736289
# 4         36.389247  0.593268  0.805005   0.736974
# ..              ...       ...       ...        ...
# 67       324.199562 -0.584964  0.811059  -0.721234
# 68       187.948172 -0.138277 -0.990394   0.139619
# 69       270.678249 -0.999930  0.011837 -84.472139
# 70       270.779159 -0.999908  0.013598 -73.530885
# 71       200.213513 -0.345520 -0.938412   0.368196
#
# [72 rows x 4 columns]

# %% [markdown]
# # Sending Data in Unstructured File Form

# %%
from skimage.io import imread
from skimage.transform import resize
from matplotlib import pyplot as plt
import matplotlib.cm as cm

example_file = ("http://upload.wikimedia.org/" +
    "wikipedia/commons/7/7d/Dog_face.png")
image = imread(example_file, as_gray=True)
plt.imshow(image, cmap=cm.gray)
plt.show()

# %%
print("data type: %s, shape: %s" %
      (type(image), image.shape))
# Out:
# data type: <class 'numpy.ndarray'>, shape: (90, 90)

# %%
image2 = image[5:70,0:70]
plt.imshow(image2, cmap=cm.gray)
plt.show()

# %%
image3 = resize(image2, (30, 30), mode='symmetric')
plt.imshow(image3, cmap=cm.gray)
print("data type: %s, shape: %s" %
      (type(image3), image3.shape))
# Out:
# data type: <class 'numpy.ndarray'>, shape: (30, 30)

# %%
image_row = image3.flatten()
print("data type: %s, shape: %s" %
      (type(image_row), image_row.shape))
# Out:
# data type: <class 'numpy.ndarray'>, shape: (900,)

# %% [markdown]
# # --------------------- Last Questions ---------------------
#
# * The installation process was simple enough to do it without issues, to check the installed packages I used Anaconda Prompt, so with this way I tried to replicate the steps in the tutorial.
# * The tutorial in the Plan of a Attack was really simple, I think that the book was more useful, so both combined were really good.
# * The main Lessons I learned was to look for cheat Sheets for markdown and keyboard shortcuts to make the coding easier, also is a good idea to see what functions can be useful in each package
